# %%
import pandas as pd
import matplotlib.pylab as plt

# %matplotlib inline

# %%
inspections_df= pd.read_csv('data/restaurant_inspections.csv', sep=';')
establishments_df= pd.read_csv('data/restaurant_establishments.csv', sep=';')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-6-f5e8157ec278> in <module>()
# ----> 1 inspections_df= pd.read_csv('data/restaurant_inspections.csv', sep=';')
#       2 establishments_df= pd.read_csv('data/restaurant_establishments.csv', sep=';')
#
# ...

# %%
yelp_df= pd.read_csv('data/all_nevada_reviews.csv')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-4-360d50392b70> in <module>()
# ----> 1 yelp_df= pd.read_csv('data/all_nevada_reviews.csv')
#
# ...

# %%
merged= inspections_df.merge(establishments_df, on= 'permit_number', how='left')

# %%
merged.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 226263 entries, 0 to 226262
# Data columns (total 37 columns):
# serial_number           226263 non-null object
# permit_number           226263 non-null object
# facility_id_x           226263 non-null object
# owner_id_x              0 non-null float64
# inspection_date         226263 non-null object
# inspection_time         226187 non-null object
# employee_id             226263 non-null object
# inspection_type_id      226263 non-null int64
# inspection_demerits     225786 non-null float64
# inspection_grade        225839 non-null object
# inspection_grade_new    225839 non-null object
# permit_status           0 non-null float64
# inspection_result       226263 non-null object
# violations              179745 non-null object
# record_updated          226263 non-null object
# Unnamed: 15             0 non-null float64
# facility_id_y           225697 non-null object
# owner_id_y              0 non-null float64
# ...

# %%
sort_merge = merged.sort_values(['facility_id_x', 'inspection_date'], ascending=[True, False])

# %%
sort_merge.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 226263 entries, 113471 to 219086
# Data columns (total 37 columns):
# serial_number           226263 non-null object
# permit_number           226263 non-null object
# facility_id_x           226263 non-null object
# owner_id_x              0 non-null float64
# inspection_date         226263 non-null object
# inspection_time         226187 non-null object
# employee_id             226263 non-null object
# inspection_type_id      226263 non-null int64
# inspection_demerits     225786 non-null float64
# inspection_grade        225839 non-null object
# inspection_grade_new    225839 non-null object
# permit_status           0 non-null float64
# inspection_result       226263 non-null object
# violations              179745 non-null object
# record_updated          226263 non-null object
# Unnamed: 15             0 non-null float64
# facility_id_y           225697 non-null object
# owner_id_y              0 non-null float64
# ...

# %%
sort_merge = sort_merge.drop(['owner_id_x','permit_status','Unnamed: 15','owner_id_y','plan_review','Unnamed: 21'], axis=1)

# %%
sort_merge.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 226263 entries, 113471 to 219086
# Data columns (total 31 columns):
# serial_number           226263 non-null object
# permit_number           226263 non-null object
# facility_id_x           226263 non-null object
# inspection_date         226263 non-null object
# inspection_time         226187 non-null object
# employee_id             226263 non-null object
# inspection_type_id      226263 non-null int64
# inspection_demerits     225786 non-null float64
# inspection_grade        225839 non-null object
# inspection_grade_new    225839 non-null object
# inspection_result       226263 non-null object
# violations              179745 non-null object
# record_updated          226263 non-null object
# facility_id_y           225697 non-null object
# PE                      225697 non-null float64
# restaurant_name         225695 non-null object
# location_name           225697 non-null object
# ...

# %%
sort_merge = sort_merge.drop(['violations', 'facility_id_y','nciaa'], axis=1)

# %%
sort_merge = sort_merge.drop(['current_grade', 'date_current', 'date_previous', 'current_demerits', 'record_status', 'previous_grade'], axis=1)

# %%
sort_merge = sort_merge.dropna(how='any')

# %%
sort_merge.head(50)
# Out:
#        serial_number permit_number facility_id_x      inspection_date  \
# 113471     DA0TB0ENO     PR0002410     FA0002024  2017-04-06 00:00:00
# 215677     DAQE9DV5Y     PR0002410     FA0002024  2016-07-14 00:00:00
# 174866     DA1563948     PR0002410     FA0002024  2015-08-20 00:00:00
# 151509     DA1179191     PR0002410     FA0002024  2014-06-27 00:00:00
# 151510     DA1179196     PR0107355     FA0002024  2014-06-27 00:00:00
# 136077     DA1108312     PR0107355     FA0002024  2013-10-01 00:00:00
# 134253     DA1098793     PR0002410     FA0002024  2013-08-27 00:00:00
# 111799     DA0995913     PR0097653     FA0002024  2012-07-06 00:00:00
# 111824     DA0996017     PR0002410     FA0002024  2012-07-06 00:00:00
# 106782     DA0965660     PR0002410     FA0002024  2012-04-09 00:00:00
# 105655     DA0953776     PR0002410     FA0002024  2012-03-22 00:00:00
# 11503      DA0092013     PR0002410     FA0002024  2011-05-09 00:00:00
# ...

# %%
sort_merge = sort_merge[sort_merge['inspection_type_id'] == 916]

# %%
sort_merge.head()
# Out:
#        serial_number permit_number facility_id_x      inspection_date  \
# 113471     DA0TB0ENO     PR0002410     FA0002024  2017-04-06 00:00:00
# 215677     DAQE9DV5Y     PR0002410     FA0002024  2016-07-14 00:00:00
# 174866     DA1563948     PR0002410     FA0002024  2015-08-20 00:00:00
# 151509     DA1179191     PR0002410     FA0002024  2014-06-27 00:00:00
# 151510     DA1179196     PR0107355     FA0002024  2014-06-27 00:00:00
#
#             inspection_time employee_id  inspection_type_id  \
# 113471  2017-04-06 13:15:00   EE7000772                 916
# 215677  2016-07-14 14:15:00   EE7000772                 916
# 174866  2015-08-20 15:25:00   EE7001125                 916
# 151509  2014-06-27 08:00:00   EE7001084                 916
# 151510  2014-06-27 08:45:00   EE7001084                 916
#
#         inspection_demerits inspection_grade inspection_grade_new  \
# 113471                  9.0                A                    A
# ...

# %%
sort_merge['last_inspection'] = sort_merge.groupby(['facility_id_x'])['inspection_date'].shift(-1)

# %%
sort_merge = sort_merge.dropna(how='any')

# %%
sort_merge.to_csv('/Users/dspitzfaden/Galvanize/capstone/data/health_inspections.csv')

# %%
len(sort_merge)
# Out:
# 198546

# %%
sort_merge.info()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-0943f51670b9> in <module>()
# ----> 1 sort_merge.info()
#
# NameError: name 'sort_merge' is not defined
